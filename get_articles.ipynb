# %%
from language_processing import *
import json
import pprint as pp
import pandas as pd
import re
import nltk
import inflect
from nltk.corpus import wordnet
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from lxml import etree
import requests

# %%
p = inflect.engine()
load_dotenv()
nltk.download('punkt');
nltk.download('averaged_perceptron_tagger');
nltk.download('wordnet');
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /Users/vonbecker/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vonbecker/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/vonbecker/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/vonbecker/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# load article lists

with open('data/articles/advanced.json') as file:
    articles_adv = json.load(file)

with open('data/articles/intermediate.json') as file:
    articles_int = json.load(file)

with open('data/articles/concise.json') as file:
    articles_con = json.load(file)

# %%
# remove articles which have an empty 'title' field

for article in articles_adv:
    if article['title'] == '':
        articles_adv.remove(article)

for article in articles_int:
    if article['title'] == '':
        articles_int.remove(article)

for article in articles_con:
    if article['title'] == '':
        articles_con.remove(article)

pp.pprint(articles_adv)
# Out:
# [{'articleId': 8,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Rosencrantz and Guildenstern'},
#  {'articleId': 20,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Othello'},
#  {'articleId': 21,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Othello'},
#  {'articleId': 30,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Much Ado About Nothing'},
#  {'articleId': 37,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Oberon'},
#  {'articleId': 41,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'King John'},
#  {'articleId': 42,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Children of Pauls'},
#  {'articleId': 43,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Measure for Measure'},
#  {'articleId': 44,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Richard II'},
#  {'articleId': 64,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Regan'},
#  {'articleId': 67,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Troilus and Cressida'},
#  {'articleId': 68,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Weird Sisters'},
#  {'articleId': 69,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Viola'},
#  {'articleId': 72,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Cordelia'},
#  {'articleId': 73,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'The Merry Wives of Windsor'},
#  {'articleId': 74,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Julius Caesar'},
#  {'articleId': 75,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'The Two Gentlemen of Verona'},
#  {'articleId': 87,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Friar Laurence'},
#  {'articleId': 97,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Pericles'},
#  {'articleId': 99,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Romeo'},
#  {'articleId': 100,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Romeo and Juliet'},
#  {'articleId': 122,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Rosalind'},
#  {'articleId': 124,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'The Taming of the Shrew'},
#  {'articleId': 128,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Titus Andronicus'},
#  {'articleId': 132,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Twelfth Night'},
#  {'articleId': 133,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'The Two Noble Kinsmen'},
#  {'articleId': 134,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'boron carbide'},
#  {'articleId': 135,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Juliet'},
#  {'articleId': 136,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Antony and Cleopatra'},
#  {'articleId': 138,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Bud Freeman'},
#  {'articleId': 139,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Charlie Haden'},
#  {'articleId': 140,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Eddie Lang'},
#  {'articleId': 141,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Albert Mangelsdorff'},
#  {'articleId': 146,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Cymbeline'},
#  {'articleId': 152,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Loves Labours Lost'},
#  {'articleId': 160,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Lady Macbeth'},
#  {'articleId': 161,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Macbeth'},
#  {'articleId': 171,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Coriolanus'},
#  {'articleId': 172,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Macbeth'},
#  {'articleId': 173,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Edward Hall'},
#  {'articleId': 176,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Timon of Athens'},
#  {'articleId': 178,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Caliban'},
#  {'articleId': 181,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'A Midsummer Nights Dream'},
#  {'articleId': 185,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Prospero'},
#  {'articleId': 186,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'The Tempest'},
#  {'articleId': 189,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Anthony Braxton'},
#  {'articleId': 190,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Lee Konitz'},
#  {'articleId': 191,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'Lennie Tristano'},
#  {'articleId': 192,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Henry V'},
#  {'articleId': 193,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-15',
#   'title': 'The Winters Tale'},
#  {'articleId': 194,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': '

#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gadsden'},
#  {'articleId': 35783,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'James Gadsden'},
#  {'articleId': 35784,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gadsden Purchase'},
#  {'articleId': 35785,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gadus'},
#  {'articleId': 35786,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'gadwall'},
#  {'articleId': 35787,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaea'},
#  {'articleId': 35788,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaekwar dynasty'},
#  {'articleId': 35789,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaelic football'},
#  {'articleId': 35790,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaelic revival'},
#  {'articleId': 35791,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaeta'},
#  {'articleId': 35792,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaetulia'},
#  {'articleId': 35793,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Grigore Gafencu'},
#  {'articleId': 35794,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaffney'},
#  {'articleId': 35795,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'gag rule'},
#  {'articleId': 35796,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'gagaku'},
#  {'articleId': 35797,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Yuri Gagarin'},
#  {'articleId': 35798,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Matilda Joslyn Gage'},
#  {'articleId': 35799,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-10-21',
#   'title': 'Thomas Gage'},
#  {'articleId': 35800,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Friedrich, baron von Gagern'},
#  {'articleId': 35801,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Hans Christoph, baron von Gagern'},
#  {'articleId': 35802,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Heinrich, baron von Gagern'},
#  {'articleId': 35803,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Maximilian, baron von Gagern'},
#  {'articleId': 35804,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Marco da Gagliano'},
#  {'articleId': 35805,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gagnoa'},
#  {'articleId': 35806,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gahadavala dynasty'},
#  {'articleId': 35807,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gahanbar'},
#  {'articleId': 35808,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Johan Gottlieb Gahn'},
#  {'articleId': 35809,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'gahnite'},
#  {'articleId': 35810,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'John Gailhard'},
#  {'articleId': 35811,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Château Gaillard'},
#  {'articleId': 35812,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaillard Cut'},
#  {'articleId': 35813,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gaillardia'},
#  {'articleId': 35814,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Battle of Gainess Mill'},
#  {'articleId': 35815,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-11-03',
#   'title': 'Gainesville'},
#  {'articleId': 35816,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gainesville'},
#  {'articleId': 35817,
#   'articleTypeId': 1,
#   'lastUpdated': '2021-06-30',
#   'title': 'Gainsborough'},
#  {
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# load search terms

with open('data/search_terms/primary_and_related.json') as file:
    all_search_terms = json.load(file)

for search_term in all_search_terms:
    search_term['related'] = [[word for word in phrase] for phrase in search_term['related']]

primary = pd.read_csv('data/search_terms/primary.csv', header=0).squeeze('columns').tolist()

primary_clean = []
for item in primary:
    parsed = item.strip('[]')
    tuple_pattern = r"\('(\w+)',\s'([A-Z]+)'\)"
    tuples = re.findall(tuple_pattern, parsed)
    primary_clean.append(tuples)

related = pd.read_csv('data/search_terms/related.csv', header=0).squeeze('columns').tolist()

related_clean = []
for item in related:
    parsed = item.strip('[]')
    tuple_pattern = r"\('(\w+)',\s'([A-Z]+)'\)"
    tuples = re.findall(tuple_pattern, parsed)
    related_clean.append(tuples)

pp.pprint(all_search_terms)
# Out:
# [{'primary': [['natural', 'JJ'], ['frequency', 'NN']],
#   'related': [[['frequency', 'NN']], [['natural', 'JJ']]],
#   'text': 'natural frequency'},
#  {'primary': [['electric', 'JJ'],
#               ['fields', 'NNS'],
#               ['and', 'CC'],
#               ['forces', 'NNS']],
#   'related': [[['field', 'NN']],
#               [['force', 'NN']],
#               [['electric', 'JJ']],
#               [['electric', 'JJ'], ['field', 'NN']],
#               [['electric', 'JJ'], ['force', 'NN']]],
#   'text': 'electric fields and forces'},
#  {'primary': [['accelerated', 'VBN'],
#               ['gravitational', 'JJ'],
#               ['motion', 'NN']],
#   'related': [[['motion', 'NN']],
#               [['accelerated', 'VBN']],
#               [['gravitational', 'JJ']],
#               [['gravitational', 'JJ'], ['motion', 'NN']],
#               [['accelerated', 'VBN'], ['motion', 'NN']]],
#   'text': 'accelerated gravitational motion'},
#  {'primary': [['afterimage', 'NN']], 'related': [], 'text': 'afterimage'},
#  {'primary': [['judgment', 'NN']], 'related': [], 'text': 'judgment'},
#  {'primary': [['thin', 'JJ'], ['films', 'NNS']],
#   'related': [[['film', 'NN']], [['thin', 'JJ']]],
#   'text': 'thin films'},
#  {'primary': [['frame', 'NN'], ['of', 'IN'], ['reference', 'NN']],
#   'related': [[['frame', 'NN']],
#               [['reference', 'NN']],
#               [['reference', 'NN'], ['frame', 'NN']]],
#   'text': 'frame of reference'},
#  {'primary': [['nodes', 'NNS'], ['and', 'CC'], ['antinodes', 'NNS']],
#   'related': [[['node', 'NN']], [['antinode', 'NN']]],
#   'text': 'nodes and antinodes'},
#  {'primary': [['sublimation', 'NN']], 'related': [], 'text': 'sublimation'},
#  {'primary': [['bernoulli', 'NNS'], ['effect', 'NN']],
#   'related': [[['bernoullis', 'NN']], [['effect', 'NN']]],
#   'text': 'bernoulli effect'},
#  {'primary': [['subtractive', 'JJ'], ['color', 'NN'], ['mixing', 'NN']],
#   'related': [[['color', 'NN']],
#               [['mixing', 'NN']],
#               [['subtractive', 'JJ']],
#               [['subtractive', 'JJ'], ['color', 'NN']],
#               [['subtractive', 'JJ'], ['mixing', 'NN']],
#               [['color', 'NN'], ['mixing', 'NN']]],
#   'text': 'subtractive color mixing'},
#  {'primary': [['size', 'NN'], ['distance', 'NN']],
#   'related': [[['size', 'NN']], [['distance', 'NN']]],
#   'text': 'size distance'},
#  {'primary': [['upwelling', 'VBG']], 'related': [], 'text': 'upwelling'},
#  {'primary': [['nonlinear', 'JJ'], ['behavior', 'NN']],
#   'related': [[['behavior', 'NN']], [['nonlinear', 'JJ']]],
#   'text': 'nonlinear behavior'},
#  {'primary': [['information', 'NN'],
#               ['processing', 'NN'],
#               ['and', 'CC'],
#               ['encoding', 'NN']],
#   'related': [[['information', 'NN']],
#               [['processing', 'NN']],
#               [['encoding', 'NN']],
#               [['information', 'NN'], ['processing', 'NN']],
#               [['information', 'NN'], ['encoding', 'NN']]],
#   'text': 'information processing and encoding'},
#  {'primary': [['resonance', 'NN']], 'related': [], 'text': 'resonance'},
#  {'primary': [['spatial', 'JJ'], ['perception', 'NN']],
#   'related': [[['perception', 'NN']], [['spatial', 'JJ']]],
#   'text': 'spatial perception'},
#  {'primary': [['attention', 'NN']], 'related': [], 'text': 'attention'},
#  {'primary': [['melting', 'VBG']], 'related': [], 'text': 'melting'},
#  {'primary': [['visual', 'JJ'], ['edge', 'NN'], ['effects', 'NNS']],
#   'related': [[['edge', 'NN']],
#               [['effect', 'NN']],
#               [['visual', 'JJ']],
#               [['visual', 'JJ'], ['edge', 'NN']],
#               [['visual', 'JJ'], ['effect', 'NN']],
#               [['edge', 'NN'], ['effect', 'NN']]],
#   'text': 'visual edge effects'},
#  {'primary': [['superposition', 'NN']], 'related': [], 'text': 'superposition'},
#  {'primary': [['exponentials', 'NNS']], 'related': [], 'text': 'exponentials'},
#  {'primary': [['surface', 'NN'],
#               ['tension', 'NN'],
#               ['of', 'IN'],
#               ['liquids', 'NNS']],
#   'related': [[['surface', 'NN']],
#               [['tension', 'NN']],
#               [['liquid', 'NN']],
#               [['surface', 'NN'], ['tension', 'NN']],
#               [['liquid', 'NN'], ['tension', 'NN']]],
#   'text': 'surface tension of liquids'},
#  {'primary': [['numbers', 'NNS']], 'related': [], 'text': 'numbers'},
#  {'primary': [['complimentary', 'JJ'], ['color', 'NN']],
#   'related': [[['color', 'NN']], [['complimentary', 'JJ']]],
#   'text': 'complimentary color'},
#  {'primary': [['binocular', 'JJ'], ['vision', 'NN']],
#   'related': [[['vision', 'NN']], [['binocular', 'JJ']]],
#   'text': 'binocular vision'},
#  {'primary': [['crystallization', 'NN']],
#   'related': [],
#   'text': 'crystallization'},
#  {'primary': [['fatigue', 'NN']], 'related': [], 'text': 'fatigue'},
#  {'primary': [['color', 'NN'], ['vision', 'NN']],
#   'related': [[['color', 'NN']], [['vision', 'NN']]],
#   'text': 'color vision'},
#  {'primary': [['oscillation', 'NN']], 'related': [], 'text': 'oscillation'},
#  {'primary': [['iridescence', 'NN']], 'related': [], 'text': 'iridescence'},
#  {'primary': [['conservation', 'NN'],
#               ['of', 'IN'],
#               ['angular', 'JJ'],
#               ['momentum', 'NN']],
#   'related': [[['conservation', 'NN']],
#               [['momentum', 'NN']],
#               [['angular', 'JJ']],
#               [['angular', 'JJ'], ['momentum', 'NN']],
#               [['conservation', 'NN'], ['of', 'IN'], ['momentum', 'NN']]],
#   'text': 'conservation of angular momentum'},
#  {'primary': [['decomposition', 'NN']], 'related': [], 'text': 'decomposition'},
#  {'primary': [['polarization', 'NN']], 'related': [], 'text': 'polarization'},
#  {'primary': [['evaporation', 'NN']], 'related': [], 'text': 'evaporation'},
#  {'primary': [['close', 'RB'], ['packing', 'VBG']],
#   'related': [[['packing', 'VBG']]],
#   'text': 'close packing'},
#  {'primary': [['ferromagnetism', 'NN']],
#   'related': [],
#   'text': 'ferromagnetism'},
#  {'primary': [['parabolas', 'NNS']], 'related': [], 'text': 'parabolas'},
#  {'primary': [['metacognition', 'NN']], 'related': [], 'text': 'metacognition'},
#  {'primary': [['albedo', 'NN']], 'related': [], 'text': 'albedo'},
#  {'primary': [['depth', 'NN'], ['perception', 'NN']],
#   'related': [[['depth', 'NN']], [['perception', 'NN']]],
#   'text': 'depth perception'},
#  {'primary': [['transverse', 'NN'], ['waves', 'NNS']],
#   'related': [[['transverse', 'NN']], [['wave', 'NN']]],
#   'text': 'transverse waves'},
#  {'primary': [['probability', 'NN']], 'related': [], 'text': 'probability'},
#  {'primary': [['shadows', 'NNS']], 'related': [], 'text': 'shadows'},
#  {'primary': [['rhythm', 'NN']], 'related': [], 'text': 'rhythm'},
#  {'primary': [['composition', 'NN'],
#               ['of', 'IN'],
#               ['perpendicular', 'JJ'],
#               ['motion', 'NN']],
#   'related': [[['composition', 'NN']],
#               [['motion', 'NN']],
#               [['perpendicular', 'JJ']],
#               [['perpendicular', 'JJ'], ['motion', 'NN']],
#               [['composition', 'NN'], ['of', 'IN'], ['motion', 'NN']]],
#   'text': 'composition of perpendicular motion'},
#  {'primary': [['simple', 'NN'], ['harmonic', 'JJ'], ['motion', 'NN']],
#   'related': [[['simple', 'NN']],
#               [['motion', 'NN']],
#               [['harmonic', 'JJ']],
#               [['harmonic', 'JJ'], ['motion', 'NN']],
#               [['simple', 'NN'], ['motion', 'NN']]],
#   'text': 'simple harmonic motion'},
#  {'primary': [['social', 'JJ'], ['loafing', 'NN']],
#   'related': [[['loafing', 'NN']], [['social', 'JJ']]],
#   'text': 'social loafing'},
#  {'primary': [['gravitational', 'JJ'], ['forces', 'NNS']],
#   'related': [[['force', 'NN']], [['gravitational', 'JJ']]],
#   'text': 'gravitational forces'},
#  {'primary': [['torque', 'NN']], 'related': [], 'text': 'torque'},
#  {'primary': [['social', 'JJ'], ['influence', 'NN']],
#   'related': [[['influence', 'NN']], [['social', 'JJ']]],
#   'text': 'social influence'},
#  {'primary': [['phase', 'NN']], 'related': [], 'text': 'phase'},
#  {'primary': [['accelerated', 'VBN'], ['rotational', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']],
#               [['accelerated', 'VBN']],
#               [['rotational', 'JJ']],
#               [['rotational', 'JJ'], ['motion', 'NN']],
#               [['accelerated', 'VBN'], ['motion', 'NN']]],
#   'text': 'accelerated rotational motion'},
#  {'primary': [['interference', 'NN']], 'related': [], 'text': 'interference'},
#  {'primary': [['standing', 'VBG'], ['waves', 'NNS']],
#   'related': [[['wave', 'NN']], [['standing', 'VBG']]],
#   'text': 'standing waves'},
#  {'primary': [['vortices', 'NNS']], 'related': [], 'text': 'vortices'},
#  {'primary': [['ionization', 'NN']], 'related': [], 'text': 'ionization'},
#  {'primary': [['prisoners', 'NNS'], ['dilemma', 'VBP']],
#   'related': [[['prisoner', 'NN']], [['dilemma', 'VBP']]],
#   'text': 'prisoners dilemma'},
#  {'primary': [['patterns', 'NNS']], 'related': [], 'text': 'patterns'},
#  {'primary': [['damping', 'VBG']], 'related': [], 'text': 'damping'},
#  {'primary': [['persistence', 'NN'], ['of', 'IN'], ['vision', 'NN']],
#   'related': [[['persistence', 'NN']],
#               [['vision', 'NN']],
#               [['vision', 'NN'], ['persistence', 'NN']]],
#   'text': 'persistence of vision'},
#  {'primary': [['coandă', 'NNS'], ['effect', 'NN']],
#   'related': [[['coandăs', 'NN']], [['effect', 'NN']]],
#   'text': 'coandă effect'},
#  {'primary': [['conservation', 'NN'], ['of', 'IN'], ['energy', 'NN']],
#   'related': [[['conservation', 'NN']],
#               [['energy', 'NN']],
#               [['energy', 'NN'], ['conservation', 'NN']]],
#   'text': 'conservation of energy'},
#  {'primary': [['reproduction', 'NN']], 'related': [], 'text': 'reproduction'},
#  {'primary': [['precession', 'NN']], 'related': [], 'text': 'precession'},
#  {'primary': [['hand', 'NN'], ['eye', 'NN'], ['coordination', 'NN']],
#   'related': [[['hand', 'NN']],
#               [['eye', 'NN']],
#               [['coordination', 'NN']],
#               [['hand', 'NN'], ['eye', 'NN']],
#               [['eye', 'NN'], ['coordination', 'NN']]],
#   'text': 'hand eye coordination'},
#  {'primary': [['wave', 'NN'], ['guide', 'NN']],
#   'related': [[['wave', 'NN']], [['guide', 'NN']]],
#   'text': 'wave guide'},
#  {'primary': [['information', 'NN'], ['and', 'CC'], ['noise', 'NN']],
#   'related': [[['information', 'NN']], [['noise', 'NN']]],
#   'text': 'information and noise'},
#  {'primary': [['pendular', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']], [['pendular', 'JJ']]],
#   'text': 'pendular motion'},
#  {'primary': [['kinetic', 'JJ'], ['energy', 'NN']],
#   'related': [[['energy', 'NN']], [['kinetic', 'JJ']]],
#   'text': 'kinetic energy'},
#  {'primary': [['real', 'JJ'], ['images', 'NNS']],
#   'related': [[['image', 'NN']], [['real', 'JJ']]],
#   'text': 'real images'},
#  {'primary': [['refraction', 'NN']], 'related': [], 'text': 'refraction'},
#  {'primary': [['parabolic', 'JJ'], ['arc', 'NN']],
#   'related': [[['arc', 'NN']], [['parabolic', 'JJ']]],
#   'text': 'parabolic arc'},
#  {'primary': [['color', 'NN'], ['mixing', 'NN']],
#   'related': [[['color', 'NN']], [['mixing', 'NN']]],
#   'text': 'color mixing'},
#  {'primary': [['light', 'JJ'], ['production', 'NN']],
#   'related': [[['production', 'NN']], [['light', 'JJ']]],
#   'text': 'light production'},
#  {'primary': [['techniques', 'NNS'],
#               ['to', 'TO'],
#               ['make', 'VB'],
#               ['the', 'DT'],
#               ['invisible', 'JJ'],
#               ['visible', 'JJ']],
#   'related': [[['technique', 'NN']],
#               [['make', 'VB']],
#               [['invisible', 'JJ']],
#               [['visible', 'JJ']]],
#   'text': 'techniques to make the invisible visible'},
#  {'primary': [['electric', 'JJ'], ['current', 'JJ']],
#   'related': [[['electric', 'JJ']], [['current', 'JJ']]],
#   'text': 'electric current'},
#  {'primary': [['linear', 'JJ'], ['inertia', 'NN']],
#   'related': [[['inertia', 'NN']], [['linear', 'JJ']]],
#   'text': 'linear inertia'},
#  {'primary': [['parallax', 'NN']], 'related': [], 'text': 'parallax'},
#  {'primary': [['phosphoresence', 'NN']],
#   'related': [],
#   'text': 'phosphoresence'},
#  {'primary': [['diffraction', 'NN']], 'related': [], 'text': 'diffraction'},
#  {'primary': [['dominant', 'JJ'], ['cues', 'NNS']],
#   'related': [[['cue', 'NN']], [['dominant', 'JJ']]],
#   'text': 'dominant cues'},
#  {'primary': [['selective', 'JJ'], ['awareness', 'NN']],
#   'related': [[['awareness', 'NN']], [['selective', 'JJ']]],
#   'text': 'selective awareness'},
#  {'primary': [['gas', 'NN'], ['flow', 'NN']],
#   'related': [[['gas', 'NN']], [['flow', 'NN']]],
#   'text': 'gas flow'},
#  {'primary': [['stereotypes', 'NNS']], 'related': [], 'text': 'stereotypes'},
#  {'primary': [['laminar', 'NN'], ['flow', 'NN']],
#   'related': [[['laminar', 'NN']], [['flow', 'NN']]],
#   'text': 'laminar flow'},
#  {'primary': [['resource', 'NN'], ['sharing', 'VBG']],
#   'related': [[['resource', 'NN']], [['sharing', 'VBG']]],
#   'text': 'resource sharing'},
#  {'primary': [['freezing', 'VBG']], 'related': [], 'text': 'freezing'},
#  {'primary': [['dispersion', 'NN']], 'related': [], 'text': 'dispersion'},
#  {'primary': [['light', 'NN'], ['gathering', 'VBG']],
#   'related': [[['light', 'NN']], [['gathering', 'VBG']]],
#   'text': 'light gathering'},
#  {'primary': [['rotational', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']], [['rotational', 'JJ']]],
#   'text': 'rotational motion'},
#  {'primary': [['randomness', 'NN']], 'related': [], 'text': 'randomness'},
#  {'primary': [['harmonics', 'NNS']], 'related': [], 'text': 'harmonics'},
#  {'primary': [['pressure', 'NN']], 'related': [], 'text': 'pressure'},
#  {'primary': [['scattering', 'VBG']], 'related': [], 'text': 'scattering'},
#  {'primary': [['social', 'JJ'], ['dilemma', 'NN']],
#   'related': [[['dilemma', 'NN']], [['social', 'JJ']]],
#   'text': 'social dilemma'},
#  {'primary': [['mental', 'JJ'], ['tasks', 'NNS']],
#   'related': [[['task', 'NN']], [['mental', 'JJ']]],
#   'text': 'mental tasks'},
#  {'primary': [['condensation', 'NN']], 'related': [], 'text': 'condensation'},
#  {'primary': [['reflection', 'NN']], 'related': [], 'text': 'reflection'},
#  {'primary': [['gyroscopics', 'NNS']], 'related': [], 'text': 'gyroscopics'},
#  {'primary': [['rotational', 'JJ'], ['inertia', 'NN']],
#   'related': [[['inertia', 'NN']], [['rotational', 'JJ']]],
#   'text': 'rotational inertia'},
#  {'primary': [['fluid', 'NN'], ['mechanics', 'NNS']],
#   'related': [[['fluid', 'NN']], [['mechanic', 'NN']]],
#   'text': 'fluid mechanics'},
#  {'primary': [['change', 'NN'], ['of', 'IN'], ['state', 'NN']],
#   'related': [[['change', 'NN']],
#               [['state', 'NN']],
#               [['state', 'NN'], ['change', 'NN']]],
#   'text': 'change of state'},
#  {'primary': [['symmetry', 'NN']], 'related': [], 'text': 'symmetry'},
#  {'primary': [['color', 'NN'], ['separation', 'NN']],
#   'related': [[['color', 'NN']], [['separation', 'NN']]],
#   'text': 'color separation'},
#  {'primary': [['phototaxis', 'NN']], 'related': [], 'text': 'phototaxis'},
#  {'primary': [['electromagnetic', 'JJ'],
#               ['radiation', 'NN'],
#               ['spectrum', 'NN']],
#   'related': [[['radiation', 'NN']],
#               [['spectrum', 'NN']],
#               [['electromagnetic', 'JJ']],
#               [['electromagnetic', 'JJ'], ['radiation', 'NN']],
#               [['electromagnetic', 'JJ'], ['spectrum', 'NN']],
#               [['radiation', 'NN'], ['spectrum', 'NN']]],
#   'text': 'electromagnetic radiation spectrum'},
#  {'primary': [['frequency', 'NN']], 'related': [], 'text': 'frequency'},
#  {'primary': [['accelerated', 'VBN'], ['linear', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']],
#               [['accelerated', 'VBN']],
#               [['linear', 'JJ']],
#               [['linear', 'JJ'], ['motion', 'NN']],
#               [['accelerated', 'VBN'], ['motion', 'NN']]],
#   'text': 'accelerated linear motion'},
#  {'primary': [['reaction', 'NN'], ['time', 'NN']],
#   'related': [[['reaction', 'NN']], [['time', 'NN']]],
#   'text': 'reaction time'},
#  {'primary': [['transformation', 'NN'], ['of', 'IN'], ['energy', 'NN']],
#   'related': [[['transformation', 'NN']],
#               [['energy', 'NN']],
#               [['energy', 'NN'], ['transformation', 'NN']]],
#   'text': 'transformation of energy'},
#  {'primary': [['emotion', 'NN']], 'related': [], 'text': 'emotion'},
#  {'primary': [['feedback', 'NN']], 'related': [], 'text': 'feedback'},
#  {'primary': [['apparent', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']], [['apparent', 'JJ']]],
#   'text': 'apparent motion'},
#  {'primary': [['atoms', 'NNS'], ['and', 'CC'], ['particles', 'NNS']],
#   'related': [[['atom', 'NN']], [['particle', 'NN']]],
#   'text': 'atoms and particles'},
#  {'primary': [['number', 'NN'], ['series', 'NN']],
#   'related': [[['number', 'NN']], [['series', 'NN']]],
#   'text': 'number series'},
#  {'primary': [['mental', 'JJ'], ['activity', 'NN']],
#   'related': [[['activity', 'NN']], [['mental', 'JJ']]],
#   'text': 'mental activity'},
#  {'primary': [['effect', 'NN'], ['of', 'IN'], ['temperature', 'NN']],
#   'related': [[['effect', 'NN']],
#               [['temperature', 'NN']],
#               [['temperature', 'NN'], ['effect', 'NN']]],
#   'text': 'effect of temperature'},
#  {'primary': [['embryonic', 'JJ'], ['development', 'NN']],
#   'related': [[['development', 'NN']], [['embryonic', 'JJ']]],
#   'text': 'embryonic development'},
#  {'primary': [['color', 'NN']], 'related': [], 'text': 'color'},
#  {'primary': [['magnetization', 'NN']], 'related': [], 'text': 'magnetization'},
#  {'primary': [['time', 'NN'],
#               ['effects', 'NNS'],
#               ['in', 'IN'],
#               ['perception', 'NN']],
#   'related': [[['time', 'NN']],
#               [['effect', 'NN']],
#               [['perception', 'NN']],
#               [['time', 'NN'], ['effect', 'NN']],
#               [['perception', 'NN'], ['effect', 'NN']]],
#   'text': 'time effects in perception'},
#  {'primary': [['motion', 'NN'], ['detection', 'NN']],
#   'related': [[['motion', 'NN']], [['detection', 'NN']]],
#   'text': 'motion detection'},
#  {'primary': [['visual', 'JJ'], ['motion', 'NN'], ['detection', 'NN']],
#   'related': [[['motion', 'NN']],
#               [['detection', 'NN']],
#               [['visual', 'JJ']],
#               [['visual', 'JJ'], ['motion', 'NN']],
#               [['visual', 'JJ'], ['detection', 'NN']],
#               [['motion', 'NN'], ['detection', 'NN']]],
#   'text': 'visual motion detection'},
#  {'primary': [['friction', 'NN']], 'related': [], 'text': 'friction'},
#  {'primary': [['economic', 'JJ'], ['exchange', 'NN']],
#   'related': [[['exchange', 'NN']], [['economic', 'JJ']]],
#   'text': 'economic exchange'},
#  {'primary': [['light', 'JJ'], ['absorption', 'NN']],
#   'related': [[['absorption', 'NN']], [['light', 'JJ']]],
#   'text': 'light absorption'},
#  {'primary': [['turbulent', 'NN'], ['flow', 'NN']],
#   'related': [[['turbulent', 'NN']], [['flow', 'NN']]],
#   'text': 'turbulent flow'},
#  {'primary': [['blackness', 'NN']], 'related': [], 'text': 'blackness'},
#  {'primary': [['modeling', 'VBG'], ['landscapes', 'NNS']],
#   'related': [[['landscape', 'NN']], [['modeling', 'VBG']]],
#   'text': 'modeling landscapes'},
#  {'primary': [['fluorescence', 'NN']], 'related': [], 'text': 'fluorescence'},
#  {'primary': [['projections', 'NNS']], 'related': [], 'text': 'projections'},
#  {'primary': [['photosynthesis', 'NN']],
#   'related': [],
#   'text': 'photosynthesis'},
#  {'primary': [['lateral', 'JJ'], ['inhibition', 'NN']],
#   'related': [[['inhibition', 'NN']], [['lateral', 'JJ']]],
#   'text': 'lateral inhibition'},
#  {'primary': [['microscopy', 'NN']], 'related': [], 'text': 'microscopy'},
#  {'primary': [['potential', 'JJ'], ['energy', 'NN']],
#   'related': [[['energy', 'NN']], [['potential', 'JJ']]],
#   'text': 'potential energy'},
#  {'primary': [['wave', 'NN'], ['excitation', 'NN']],
#   'related': [[['wave', 'NN']], [['excitation', 'NN']]],
#   'text': 'wave excitation'},
#  {'primary': [['periodic', 'JJ'], ['motion', 'NN']],
#   'related': [[['motion', 'NN']], [['periodic', 'JJ']]],
#   'text': 'periodic motion'},
#  {'primary': [['biases', 'NNS']], 'related': [], 'text': 'biases'},
#  {'primary': [['electromagnetic', 'JJ'], ['forces', 'NNS']],
#   'related': [[['force', 'NN']], [['electromagnetic', 'JJ']]],
#   'text': 'electromagnetic forces'},
#  {'primary': [['amibiguous', 'JJ'], ['cues', 'NNS']],
#   'related': [[['cue', 'NN']], [['amibiguous', 'JJ']]],
#   'text': 'amibiguous cues'},
#  {'primary': [['image', 'NN'], ['formation', 'NN']],
#   'related': [[['image', 'NN']], [['formation', 'NN']]],
#   'text': 'image formation'},
#  {'primary': [['parabolic', 'JJ'], ['mirrors', 'NNS']],
#   'related': [[['mirror', 'NN']], [['parabolic', 'JJ']]],
#   'text': 'parabolic mirrors'},
#  {'primary': [['wind', 'NN']], 'related': [], 'text': 'wind'},
#  {'primary': [['lenses', 'NNS']], 'related': [], 'text': 'lenses'},
#  {'primary': [['center', 'NN'], ['of', 'IN'], ['gravity', 'NN']],
#   'related': [[['center', 'NN']],
#               [['gravity', 'NN']],
#               [['gravity', 'NN'], ['center', 'NN']]],
#   'text': 'center of gravity'},
#  {'primary': [['vibration', 'NN']], 'related': [], 'text': 'vibration'},
#  {'primary': [['weather', 'NN']], 'related': [], 'text': 'weather'},
#  {'primary': [['identity', 'NN']], 'related': [], 'text': 'identity'},
#  {'primary': [['cornsweet', 'NN'], ['illusion', 'NN']],
#   'related': [[['cornsweet', 'NN']], [['illusion', 'NN']]],
#   'text': 'cornsweet illusion'},
#  {'primary': [['acoustics', 'NNS']], 'related': [], 'text': 'acoustics'},
#  {'primary': [['evaporation', 'NN']], 'related': [], 'text': 'evaporation'},
#  {'primary': [['chicken', 'NN'], ['wire', 'NN']],
#   'related': [[['chicken', 'NN']], [['wire', 'NN']]],
#   'text': 'chicken wire'},
#  {'primary': [['ocean', 'NN']], 'related': [], 'text': 'ocean'},
#  {'primary': [['sharks', 'NNS']], 'related': [], 'text': 'sharks'},
#  {'primary': [['neon', 'NN']], 'related': [], 'text': 'neon'},
#  {'primary': [['migrations', 'NNS']], 'related': [], 'text': 'migrations'},
#  {'primary': [['huygens', 'NNS'], ['principle', 'NN']],
#   'related': [[['huygen', 'NN']], [['principle', 'NN']]],
#   'text': 'huygens principle'},
#  {'primary': [['mirrors', 'NNS']], 'related': [], 'text': 'mirrors'},
#  {'primary': [['turbulence', 'NN']], 'related': [], 'text': 'turbulence'},
#  {'primary': [['carbon', 'NN'], ['dioxide', 'NN']],
#   'related': [[['carbon', 'NN']], [['dioxide', 'NN']]],
#   'text': 'carbon dioxide'},
#  {'primary': [['parallel', 'NN']], 'related': [], 'text': 'parallel'},
#  {'primary': [['phase', 'NN'], ['angle', 'NN']],
#   'related': [[['phase', 'NN']], [['angle', 'NN']]],
#   'text': 'phase angle'},
#  {'primary': [['parabolas', 'NNS']], 'related': [], 'text': 'parabolas'},
#  {'primary': [['organisms', 'NNS']], 'related': [], 'text': 'organisms'},
#  {'primary': [['cosmic', 'JJ'], ['rays', 'NNS']],
#   'related': [[['ray', 'NN']], [['cosmic', 'JJ']]],
#   'text': 'cosmic rays'},
#  {'primary': [['simultaneous', 'JJ'], ['contrast', 'NN']],
#   'related': [[['contrast', 'NN']], [['simultaneous', 'JJ']]],
#   'text': 'simultaneous contrast'},
#  {'primary': [['series', 'NN']], 'related': [], 'text': 'series'},
#  {'primary': [['chaos', 'NN']], 'related': [], 'text': 'chaos'},
#  {'primary': [['amplification', 'NN']], 'related': [], 'text': 'amplification'},
#  {'primary': [['genetics', 'NNS']], 'related': [], 'text': 'genetics'},
#  {'primary': [['lasers', 'NNS']], 'related': [], 'text': 'lasers'},
#  {'primary': [['artwork', 'NN']], 'related': [], 'text': 'artwork'},
#  {'primary': [['membrane', 'NN']], 'related': [], 'text': 'membrane'},
#  {'primary': [['newtons', 'NNS'], ['laws', 'NNS']],
#   'related': [[['newton', 'NN']], [['law', 'NN']]],
#   'text': 'newtons laws'},
#  {'primary': [['reflections', 'NNS']], 'related': [], 'text': 'reflections'},
#  {'primary': [['ratio', 'NN']], 'related': [], 'text': 'ratio'},
#  {'primary': [['circuit', 'NN']], 'related': [], 'text': 'circuit'},
#  {'primary': [['ping', 'VBG'], ['pong', 'NN'], ['balls', 'NNS']],
#   'related': [[['pong', 'NN']],
#               [['ball', 'NN']],
#               [['ping', 'VBG']],
#               [['pong', 'NN'], ['ball', 'NN']],
#               [['ping', 'VBG'], ['pong', 'NN']]],
#   'text': 'ping pong balls'},
#  {'primary': [['dna', 'NN']], 'related': [], 'text': 'dna'},
#  {'primary': [['levitation', 'NN']], 'related': [], 'text': 'levitation'},
#  {'primary': [['navigation', 'NN']], 'related': [], 'text': 'navigation'},
#  {'primary': [['curves', 'NNS']], 'related': [], 'text': 'curves'},
#  {'primary': [['illusions', 'NNS']], 'related': [], 'text': 'illusions'},
#  {'primary': [['model', 'NN'], ['organisms', 'NNS']],
#   'related': [[['model', 'NN']], [['organism', 'NN']]],
#   'text': 'model organisms'},
#  {'primary': [['whales', 'NNS']], 'related': [], 'text': 'whales'},
#  {'primary': [['gases', 'NNS']], 'related': [], 'text': 'gases'},
#  {'primary': [['portraits', 'NNS']], 'related': [], 'text': 'portraits'},
#  {'primary': [['sun', 'NN']], 'related': [], 'text': 'sun'},
#  {'primary': [['bicycle', 'NN'], ['wheel', 'NN']],
#   'related': [[['bicycle', 'NN']], [['wheel', 'NN']]],
#   'text': 'bicycle wheel'},
#  {'primary': [['speakers', 'NNS']], 'related': [], 'text': 'speakers'},
#  {'primary': [['identical', 'JJ'], ['twins', 'NNS']],
#   'related': [[['twin', 'NN']], [['identical', 'JJ']]],
#   'text': 'identical twins'},
#  {'primary': [['pendulums', 'NNS']], 'related': [], 'text': 'pendulums'},
#  {'primary': [['dissection', 'NN']], 'related': [], 'text': 'dissection'},
#  {'primary': [['eyes', 'NNS']], 'related': [], 'text': 'eyes'},
#  {'primary': [['nerves', 'NNS']], 'related': [], 'text': 'nerves'},
#  {'primary': [['wind', 'NN']], 'related': [], 'text': 'wind'},
#  {'primary': [['zebrafish', 'NN']], 'related': [], 'text': 'zebrafish'},
#  {'primary': [['heat', 'NN'], ['transfer', 'NN']],
#   'related': [[['heat', 'NN']], [['transfer', 'NN']]],
#   'text': 'heat transfer'},
#  {'primary': [['volcanoes', 'NNS']], 'related': [], 'text': 'volcanoes'},
#  {'primary': [['marine', 'NN']], 'related': [], 'text': 'marine'},
#  {'primary': [['pacific', 'NN']], 'related': [], 'text': 'pacific'},
#  {'primary': [['complexity', 'NN']], 'related': [], 'text': 'complexity'},
#  {'primary': [['turtles', 'NNS']], 'related': [], 'text': 'turtles'},
#  {'primary': [['condensation', 'NN']], 'related': [], 'text': 'condensation'},
#  {'primary': [['appearance', 'NN']], 'related': [], 'text': 'appearance'},
#  {'primary': [['unicellular', 'JJ'], ['organisms', 'NNS']],
#   'related': [[['organism', 'NN']], [['unicellular', 'JJ']]],
#   'text': 'unicellular organisms'},
#  {'primary': [['tides', 'NNS']], 'related': [], 'text': 'tides'},
#  {'primary': [['ganzfeld', 'NN'], ['effect', 'NN']],
#   'related': [[['ganzfeld', 'NN']], [['effect', 'NN']]],
#   'text': 'ganzfeld effect'},
#  {'primary': [['afterimage', 'NN']], 'related': [], 'text': 'afterimage'},
#  {'primary': [['fragmentation', 'NN']], 'related': [], 'text': 'fragmentation'},
#  {'primary': [['cmy', 'NN'], ['retina', 'NN']],
#   'related': [[['cmy', 'NN']], [['retina', 'NN']]],
#   'text': 'cmy retina'},
#  {'primary': [['balance', 'NN']], 'related': [], 'text': 'balance'},
#  {'primary': [['boundary', 'NN']], 'related': [], 'text': 'boundary'},
#  {'primary': [['magnetic', 'JJ'], ['field', 'NN']],
#   'related': [[['field', 'NN']], [['magnetic', 'JJ']]],
#   'text': 'magnetic field'},
#  {'primary': [['photography', 'NN']], 'related': [], 'text': 'photography'},
#  {'primary': [['chladni', 'NN']], 'related': [], 'text': 'chladni'},
#  {'primary': [['spinning', 'VBG']], 'related': [], 'text': 'spinning'},
#  {'primary': [['wavelength', 'NN']], 'related': [], 'text': 'wavelength'},
#  {'primary': [['cells', 'NNS']], 'related': [], 'text': 'cells'},
#  {'primary': [['prisms', 'NNS']], 'related': [], 'text': 'prisms'},
#  {'primary': [['pressure', 'NN']], 'related': [], 'text': 'pressure'},
#  {'primary': [['water', 'NN']], 'related': [], 'text': 'water'},
#  {'primary': [['proportion', 'NN']], 'related': [], 'text': 'proportion'},
#  {'primary': [['earthquakes', 'NNS']], 'related': [], 'text': 'earthquakes'},
#  {'primary': [['attentive', 'JJ'], ['listening', 'NN']],
#   'related': [[['listening', 'NN']], [['attentive', 'JJ']]],
#   'text': 'attentive listening'},
#  {'primary': [['rotation', 'NN']], 'related': [], 'text': 'rotation'},
#  {'primary': [['electrolysis', 'NN']], 'related': [], 'text': 'electrolysis'},
#  {'primary': [['sand', 'NN']], 'related': [], 'text': 'sand'},
#  {'primary': [['equilibrium', 'NN']], 'related': [], 'text': 'equilibrium'},
#  {'primary': [['human', 'JJ'],
#               ['traits', 'VBZ'],
#               ['genetics', 'NNS'],
#               ['environment', 'NN'],
#               ['nature', 'NN'],
#               ['nurture', 'NN'],
#               ['inheritance', 'NN'],
#               ['diversity', 'NN']],
#   'related': [[['genetic', 'NN']],
#               [['environment', 'NN']],
#               [['nature', 'NN']],
#               [['nurture', 'NN']],
#               [['inheritance', 'NN']],
#               [['diversity', 'NN']],
#               [['traits', 'VBZ']],
#               [['human', 'JJ']],
#               [['genetic', 'NN'], ['environment', 'NN']],
#               [['environment', 'NN'], ['nature', 'NN']],
#               [['nature', 'NN'], ['nurture', 'NN']],
#               [['nurture', 'NN'], ['inheritance', 'NN']],
#               [['inheritance', 'NN'], ['diversity', 'NN']],
#               [['traits', 'VBZ'], ['genetic', 'NN']]],
#   'text': 'human traits genetics environment nature nurture inheritance '
#           'diversity'},
#  {'primary': [['magnification', 'NN']], 'related': [], 'text': 'magnification'},
#  {'primary': [['habitat', 'NN']], 'related': [], 'text': 'habitat'},
#  {'primary': [['stroop', 'NN'], ['effect', 'NN']],
#   'related': [[['stroop', 'NN']], [['effect', 'NN']]],
#   'text': 'stroop effect'},
#  {'primary': [['rgb', 'NN']], 'related': [], 'text': 'rgb'},
#  {'primary': [['fish', 'NN'], ['eggs', 'NNS']],
#   'related': [[['fish', 'NN']], [['egg', 'NN']]],
#   'text': 'fish eggs'},
#  {'primary': [['soap', 'NN']], 'related': [], 'text': 'soap'},
#  {'primary': [['cooperation', 'NN']], 'related': [], 'text': 'cooperation'},
#  {'primary': [['scale', 'NN']], 'related': [], 'text': 'scale'},
#  {'primary': [['focal', 'JJ'], ['point', 'NN']],
#   'related': [[['point', 'NN']], [['focal', 'JJ']]],
#   'text': 'focal point'},
#  {'primary': [['perspective', 'NN']], 'related': [], 'text': 'perspective'},
#  {'primary': [['magnet', 'NN']], 'related': [], 'text': 'magnet'},
#  {'primary': [['musical', 'JJ'], ['instruments', 'NNS']],
#   'related': [[['instrument', 'NN']], [['musical', 'JJ']]],
#   'text': 'musical instruments'},
#  {'primary': [['comets', 'NNS']], 'related': [], 'text': 'comets'},
#  {'primary': [['cmy', 'NN']], 'related': [], 'text': 'cmy'},
#  {'primary': [['embryology', 'NN']], 'related': [], 'text': 'embryology'},
#  {'primary': [['model', 'NN']], 'related': [], 'text': 'model'},
#  {'primary': [['adaptation', 'NN']], 'related': [], 'text': 'adaptation'},
#  {'primary': [['sundial', 'JJ']], 'related': [], 'text': 'sundial'},
#  {'primary': [['plankton', 'NN']], 'related': [], 'text': 'plankton'},
#  {'primary': [['fog', 'NN']], 'related': [], 'text': 'fog'},
#  {'primary': [['skin', 'NN']], 'related': [], 'text': 'skin'},
#  {'primary': [['cells', 'NNS'], ['movement', 'NN'], ['animation', 'NN']],
#   'related': [[['cell', 'NN']],
#               [['movement', 'NN']],
#               [['animation', 'NN']],
#               [['cell', 'NN'], ['movement', 'NN']],
#               [['movement', 'NN'], ['animation', 'NN']]],
#   'text': 'cells movement animation'},
#  {'primary': [['moon', 'NN']], 'related': [], 'text': 'moon'},
#  {'primary': [['human', 'JJ'], ['generosity', 'NN'], ['project', 'NN']],
#   'related': [[['generosity', 'NN']],
#               [['project', 'NN']],
#               [['human', 'JJ']],
#               [['human', 'JJ'], ['generosity', 'NN']],
#               [['human', 'JJ'], ['project', 'NN']],
#               [['generosity', 'NN'], ['project', 'NN']]],
#   'text': 'human generosity project'},
#  {'primary': [['air', 'NN'], ['currents', 'NNS']],
#   'related': [[['air', 'NN']], [['current', 'NN']]],
#   'text': 'air currents'},
#  {'primary': [['gravity', 'NN']], 'related': [], 'text': 'gravity'},
#  {'primary': [['bubbles', 'NNS']], 'related': [], 'text': 'bubbles'}]

# %%
def get_text(phrase):
    text = ' '.join(word[0] for word in phrase)
    return text

def get_pos(word):
    tag = word[1]
    if tag.startswith('N'):
        label = 'n'
    elif tag.startswith('V'):
        label = 'v'
    elif tag.startswith('J'):
        label = 'a'
    elif tag.startswith('R'):
        label = 'r'
    else:
        label = 'z'
    return label

# %%
# get synonyms for a given tagged word

def get_syns(word):
    text = get_text([word])
    label = get_pos(word)

    syns = wordnet.synsets(text)

    these_syns = []
    for syn in syns:
        if syn in these_syns:
            continue
        if syn.pos() == label:
            these_syns.append(syn)

    syns_flat = [item for sublist in [syn.lemma_names() for syn in these_syns] for item in sublist]

    syns_flat_unique = []
    [syns_flat_unique.append(item) for item in syns_flat if item not in syns_flat_unique]

    all_syns = [syn.replace('_', ' ') for syn in syns_flat_unique]

    non_triv_syns = [syn for syn in all_syns if syn != text]
    return non_triv_syns

# %%
# get similar search phrases using synonyms

def get_similar(search_phrase):
    num_words = len(search_phrase)
    sim_phrases = []
    for i in range(num_words):
        phrase_text = get_text(search_phrase)
        phrase_text_split = phrase_text.split()
        syns = get_syns(search_phrase[i])
        # print(syns)
        syns_unique = []
        [syns_unique.append(x) for x in syns if x not in syns_unique]
        for j in range(len(syns_unique)):
            sim_phrase = phrase_text_split
            sim_phrase[i] = syns_unique[j]
            sim_phrase_text = ' '.join(sim_phrase)
            sim_phrases.append(sim_phrase_text)
    return sim_phrases

# %%
# get the britannica artitle titles listed under topic = search_text
# www.britannica.com/topic/search-text

def get_britannica_topic_titles(search_text):
    search_text = '-'.join(search_text.split())
    url = 'https://www.britannica.com/topic/{}'.format(search_text)
    webpage = requests.get(url)
    soup = BeautifulSoup(webpage.content, "html.parser")
    content = etree.HTML(str(soup))
    titles = content.xpath('//section[@class="index-entries"]//span[@class="index-xref"]/a/text()')
    titles = [title.split(': ')[0] for title in titles]
    return titles

# get the articleId of articles having title = text
# source = articles_adv, articles_con, or articles_int

def get_articles_by_title(text, source):
    matches = [article for article in source if article['title'] == text]
    return matches

# %%
# get metadata for article matches
# currently, matches are only from articles_adv

sources = [articles_adv, articles_con, articles_int]

article_matches = []

def get_articles(search_text, source, matches):
    new_matches = get_articles_by_title(search_text, source)
    new_matches = [match for match in new_matches if match not in matches]
    matches += new_matches
    if not new_matches and source == articles_adv:
        titles = get_britannica_topic_titles(search_text)
        unique_titles = []
        [unique_titles.append(x) for x in titles if x not in unique_titles]
        for title in [title for title in unique_titles if title not in [match['title'] for match in matches]]:
            new_matches += get_articles_by_title(title, source)
        matches += new_matches
    return matches

for item in all_search_terms:
    these_matches = {'title': item['text'],
                       'primary': [],
                       'related': []}
    matches = []
    search_text = item['text']
    for source in sources:
        matches += get_articles(search_text, source, matches)
    these_matches['primary'] += matches
    num_related = len(item['related'])
    if not matches and num_related > 0:
        for i in range(num_related):
            search_text = get_text(item['related'][i])
            for source in sources:
                matches += get_articles(search_text, articles_adv, matches)
            these_matches['related'] += matches
    article_matches.append(these_matches)

pp.pprint(article_matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 4
#       1 # get metadata for article matches
#       2 # currently, matches are only from articles_adv
# ----> 4 sources = [articles_adv, articles_con, articles_int]
#       6 article_matches = []
#       8 def get_articles(search_text, source, matches):
#
# NameError: name 'articles_adv' is not defined

# %%
get_articles_by_title('information processing', articles_adv)
# Out:
# [{'articleId': 106312,
#   'articleTypeId': 1,
#   'title': 'information processing',
#   'lastUpdated': '2021-07-01'}]

# %%
# get_articles_by_title('natural frequency', articles_adv)
get_britannica_topic_titles('natural-frequency')
# Out:
# ['mechanics', 'spectroscopy', 'analysis', 'wave']
